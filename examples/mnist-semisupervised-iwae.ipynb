# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.nn import Parameter
import sys
sys.path.append('../')
import probtorch
print('probtorch:', probtorch.__version__, 
      'torch:', torch.__version__, 
      'cuda:', torch.cuda.is_available())
# Out:
# probtorch: 0.0+57773f0 torch: 0.2.0+bdeee47 cuda: True

# %%
from functools import wraps

# TODO: move this into probtorch.util
def expand_inputs(f):
    @wraps(f)
    def g(*args, num_samples=None, **kwargs):
        if not num_samples is None:
            new_args = []
            new_kwargs = {}
            for arg in args:
                if hasattr(arg, 'expand'):
                    new_args.append(arg.expand(num_samples, *arg.size()))
                else:
                    new_args.append(arg)
            for k in kwargs:
                arg = kwargs[k]
                if hasattr(arg, 'expand'):
                    new_args.append(arg.expand(num_samples, *arg.size()))
                else:
                    new_args.append(arg)
            return f(*new_args, num_samples=num_samples, **new_kwargs)
        else:
            return f(*args, num_samples=None, **kwargs)
    return g

# %% [markdown]
# # Parameters

# %%
# model parameters
NUM_PIXELS = 784
NUM_HIDDEN = 256
NUM_DIGITS = 10
NUM_STYLE = 50   

# training parameters
NUM_SAMPLES = 8 
NUM_BATCH = 128
NUM_EPOCHS = 200
LABEL_FRACTION = 0.1
LEARNING_RATE = 1e-3
BETA1 = 0.90
EPS = 1e-9
CUDA = torch.cuda.is_available()
#CUDA = False

# path parameters
MODEL_NAME = 'mnist-semisupervised-iwae-%02ddim' % NUM_STYLE
DATA_PATH = '../data'
WEIGHTS_PATH = '../weights'
RESTORE = False

# %%
# if this code does not run, then disable CUDA
if CUDA:
    v = Variable(torch.rand(2,3,4).cuda())
    torch.nn.functional.softmax(v, v.dim()-1)

# %% [markdown]
# # Encoder Model

# %%
class Encoder(nn.Module):
    def __init__(self, num_pixels=NUM_PIXELS, 
                       num_hidden=NUM_HIDDEN,
                       num_digits=NUM_DIGITS,
                       num_style=NUM_STYLE,
                       num_batch=NUM_BATCH):
        super(self.__class__, self).__init__()
        self.enc_hidden = nn.Sequential( 
                            nn.Linear(num_pixels, num_hidden),
                            nn.ReLU())
        self.digit_log_weights = nn.Linear(num_hidden, num_digits)
        self.digit_temp = 0.66
        self.style_mean = nn.Linear(num_hidden + num_digits, num_style)
        self.style_log_std = nn.Linear(num_hidden + num_digits, num_style)
    
    @expand_inputs
    def forward(self, images, labels=None, num_samples=None):
        q = probtorch.Trace()
        hiddens = self.enc_hidden(images) 
        digits = q.concrete(self.digit_log_weights(hiddens),
                            self.digit_temp,
                            value=labels,
                            name='digits')
        hiddens2 = torch.cat([digits, hiddens], -1)
        styles_mean = self.style_mean(hiddens2)
        styles_std = torch.exp(self.style_log_std(hiddens2))
        q.normal(styles_mean,
                 styles_std,
                 name='styles')
        return q

# %% [markdown]
# # Decoder Model

# %%
class Decoder(nn.Module):
    def __init__(self, num_pixels=NUM_PIXELS, 
                       num_hidden=NUM_HIDDEN,
                       num_digits=NUM_DIGITS,
                       num_style=NUM_STYLE):
        super(self.__class__, self).__init__()
        self.num_digits = num_digits
        self.digit_log_weights = Parameter(torch.zeros(num_digits))
        self.digit_temp = 0.66
        self.style_mean = Parameter(torch.zeros(num_style))
        self.style_log_std = Parameter(torch.zeros(num_style))
        self.dec_hidden = nn.Sequential(
                            nn.Linear(num_style + num_digits, num_hidden),
                            nn.ReLU())
        self.dec_image = nn.Sequential(
                           nn.Linear(num_hidden, num_pixels),
                           nn.Sigmoid())

    def forward(self, images=None, q=None):
        p = probtorch.Trace()
        digits = p.concrete(self.digit_log_weights, self.digit_temp,
                            value=q['digits'],
                            name='digits')
        styles = p.normal(0.0, 1.0,
                          value=q['styles'],
                          name='styles')
        hiddens = self.dec_hidden(torch.cat([digits, styles], -1))
        images_mean = self.dec_image(hiddens)
        p.loss(lambda x_hat, x: -(torch.log(x_hat + EPS) * x + 
                                  torch.log(1 - x_hat + EPS) * (1-x)).sum(-1),
               images_mean, images, name='images')
        return p

# %% [markdown]
# # Loss

# %%
def elbo(q, p, alpha=0.1):
    if NUM_SAMPLES is None:
        return probtorch.objectives.importance.elbo(q, p, sample_dim=None, batch_dim=0, alpha=alpha)
    else:
        return probtorch.objectives.importance.elbo(q, p, sample_dim=0, batch_dim=1, alpha=alpha)

# %% [markdown]
# # Data

# %%
from torchvision import datasets, transforms
import os 

if not os.path.isdir(DATA_PATH):
    os.makedirs(DATA_PATH)

train_data = torch.utils.data.DataLoader(
                datasets.MNIST(DATA_PATH, train=True, download=True,
                               transform=transforms.ToTensor()),
                batch_size=NUM_BATCH, shuffle=True) 
test_data = torch.utils.data.DataLoader(
                datasets.MNIST(DATA_PATH, train=False, download=True,
                               transform=transforms.ToTensor()),
                batch_size=NUM_BATCH, shuffle=True)

# %% [markdown]
# # Training and Testing

# %%
enc = Encoder()
dec = Decoder()
if CUDA:
    enc.cuda()
    dec.cuda()
optimizer =  torch.optim.Adam(list(enc.parameters())+list(dec.parameters()),
                              lr=LEARNING_RATE,
                              betas=(BETA1, 0.999))

# %%
def train(data, enc, dec, optimizer, 
          label_mask={}, label_fraction=LABEL_FRACTION):
    epoch_elbo = 0.0
    enc.train()
    dec.train()
    N = 0
    for b, (images, labels) in enumerate(data):
        if images.size()[0] == NUM_BATCH:
            N += NUM_BATCH
            images = images.view(-1, NUM_PIXELS)
            labels_onehot = torch.zeros(NUM_BATCH, NUM_DIGITS)
            labels_onehot.scatter_(1, labels.unsqueeze(1), 1)
            labels_onehot = torch.clamp(labels_onehot, EPS, 1-EPS)
            if CUDA:
                images = images.cuda()
                labels_onehot = labels_onehot.cuda()
            images = Variable(images)
            labels_onehot = Variable(labels_onehot)
            optimizer.zero_grad()
            if b not in label_mask:
                label_mask[b] = (random() < label_fraction)
            if label_mask[b]:
                q = enc(images, labels_onehot, num_samples=NUM_SAMPLES)
            else:
                q = enc(images, num_samples=NUM_SAMPLES)
            p = dec(images, q)
            loss = -elbo(q, p)
            loss.backward()
            optimizer.step()
            if CUDA:
                loss = loss.cpu()
            epoch_elbo -= loss.data.numpy()[0]
    return epoch_elbo / N, label_mask

def test(data, enc, dec, infer=True):
    enc.eval()
    dec.eval()
    epoch_elbo = 0.0
    epoch_correct = 0
    N = 0
    for b, (images, labels) in enumerate(data):
        if images.size()[0] == NUM_BATCH:
            N += NUM_BATCH
            images = images.view(-1, NUM_PIXELS)
            if CUDA:
                images = images.cuda()
            images = Variable(images)
            q = enc(images, num_samples=NUM_SAMPLES)
            p = dec(images, q)
            batch_elbo = elbo(q, p)
            if CUDA:
                batch_elbo = batch_elbo.cpu()
            epoch_elbo += batch_elbo.data.numpy()[0]
            if infer:
                log_p = p.log_joint(0, 1)
                log_q = q.log_joint(0, 1)
                log_w = log_p - log_q
                w = torch.nn.functional.softmax(log_w, 0)
                y_samples = q['digits'].value
                y_expect = (w.unsqueeze(-1) * y_samples).sum(0)
                _ , y_pred = y_expect.data.max(-1)
                if CUDA:
                    y_pred = y_pred.cpu()
                epoch_correct += (labels == y_pred).sum()
            else:
                _, y_pred = q['digits'].value.data.max(-1)
                if CUDA:
                    y_pred = y_pred.cpu()
                epoch_correct += (labels == y_pred).sum()*1.0 / (NUM_SAMPLES or 1.0)
    return epoch_elbo / N, epoch_correct / N

# %%
import time
from random import random
if not RESTORE:
    mask = {}
    for e in range(NUM_EPOCHS):
        train_start = time.time()
        train_elbo, mask = train(train_data, enc, dec, 
                                 optimizer, mask, LABEL_FRACTION)
        train_end = time.time()
        test_start = time.time()
        test_elbo, test_accuracy = test(test_data, enc, dec)
        test_end = time.time()
        print('[Epoch %d] Train: ELBO %.4e (%ds) Test: ELBO %.4e, Accuracy %0.3f (%ds)' % (
                e, train_elbo, train_end - train_start, 
                test_elbo, test_accuracy, test_end - test_start))

    if not os.path.isdir(WEIGHTS_PATH):
        os.mkdir(WEIGHTS_PATH)
    torch.save(enc.state_dict(),
               '%s/%s-%s-%s-enc.rar' % (WEIGHTS_PATH, MODEL_NAME, probtorch.__version__, torch.__version__))
    torch.save(dec.state_dict(),
               '%s/%s-%s-%s-dec.rar' % (WEIGHTS_PATH, MODEL_NAME, probtorch.__version__, torch.__version__))
# Out:
# [Epoch 0] Train: ELBO -1.3309e+00 (7s) Test: ELBO -1.0656e+00, Accuracy 0.113 (1s)
# [Epoch 1] Train: ELBO -1.0126e+00 (7s) Test: ELBO -9.5411e-01, Accuracy 0.116 (1s)
# [Epoch 2] Train: ELBO -9.3953e-01 (7s) Test: ELBO -9.0890e-01, Accuracy 0.152 (0s)
# [Epoch 3] Train: ELBO -8.9670e-01 (7s) Test: ELBO -8.7074e-01, Accuracy 0.479 (1s)
# [Epoch 4] Train: ELBO -8.6731e-01 (7s) Test: ELBO -8.5049e-01, Accuracy 0.662 (0s)
# [Epoch 5] Train: ELBO -8.4968e-01 (7s) Test: ELBO -8.3409e-01, Accuracy 0.709 (0s)
# [Epoch 6] Train: ELBO -8.3645e-01 (7s) Test: ELBO -8.2475e-01, Accuracy 0.730 (1s)
# [Epoch 7] Train: ELBO -8.2799e-01 (7s) Test: ELBO -8.1890e-01, Accuracy 0.792 (0s)
# [Epoch 8] Train: ELBO -8.2064e-01 (7s) Test: ELBO -8.1149e-01, Accuracy 0.812 (1s)
# [Epoch 9] Train: ELBO -8.1477e-01 (7s) Test: ELBO -8.0636e-01, Accuracy 0.832 (1s)
# [Epoch 10] Train: ELBO -8.0983e-01 (7s) Test: ELBO -8.0304e-01, Accuracy 0.836 (0s)
# [Epoch 11] Train: ELBO -8.0591e-01 (7s) Test: ELBO -7.9948e-01, Accuracy 0.844 (1s)
# [Epoch 12] Train: ELBO -8.0246e-01 (7s) Test: ELBO -7.9563e-01, Accuracy 0.847 (0s)
# [Epoch 13] Train: ELBO -7.9916e-01 (7s) Test: ELBO -7.9262e-01, Accuracy 0.863 (0s)
# [Epoch 14] Train: ELBO -7.9643e-01 (7s) Test: ELBO -7.9025e-01, Accuracy 0.867 (0s)
# [Epoch 15] Train: ELBO -7.9403e-01 (7s) Test: ELBO -7.8870e-01, Accuracy 0.869 (1s)
# [Epoch 16] Train: ELBO -7.9191e-01 (7s) Test: ELBO -7.8641e-01, Accuracy 0.872 (0s)
# [Epoch 17] Train: ELBO -7.8964e-01 (7s) Test: ELBO -7.8475e-01, Accuracy 0.880 (0s)
# [Epoch 18] Train: ELBO -7.8825e-01 (7s) Test: ELBO -7.8274e-01, Accuracy 0.885 (1s)
# [Epoch 19] Train: ELBO -7.8644e-01 (7s) Test: ELBO -7.8180e-01, Accuracy 0.888 (0s)
# [Epoch 20] Train: ELBO -7.8481e-01 (7s) Test: ELBO -7.7945e-01, Accuracy 0.884 (0s)
# [Epoch 21] Train: ELBO -7.8357e-01 (7s) Test: ELBO -7.7959e-01, Accuracy 0.890 (1s)
# [Epoch 22] Train: ELBO -7.8229e-01 (7s) Test: ELBO -7.7895e-01, Accuracy 0.895 (1s)
# [Epoch 23] Train: ELBO -7.8125e-01 (7s) Test: ELBO -7.7746e-01, Accuracy 0.892 (0s)
# [Epoch 24] Train: ELBO -7.7999e-01 (7s) Test: ELBO -7.7525e-01, Accuracy 0.897 (1s)
# [Epoch 25] Train: ELBO -7.7911e-01 (7s) Test: ELBO -7.7516e-01, Accuracy 0.900 (1s)
# [Epoch 26] Train: ELBO -7.7835e-01 (7s) Test: ELBO -7.7435e-01, Accuracy 0.903 (1s)
# [Epoch 27] Train: ELBO -7.7736e-01 (7s) Test: ELBO -7.7410e-01, Accuracy 0.903 (0s)
# [Epoch 28] Train: ELBO -7.7660e-01 (7s) Test: ELBO -7.7292e-01, Accuracy 0.904 (1s)
# [Epoch 29] Train: ELBO -7.7571e-01 (7s) Test: ELBO -7.7240e-01, Accuracy 0.904 (1s)
# [Epoch 30] Train: ELBO -7.7514e-01 (8s) Test: ELBO -7.7235e-01, Accuracy 0.905 (1s)
# [Epoch 31] Train: ELBO -7.7448e-01 (7s) Test: ELBO -7.7113e-01, Accuracy 0.906 (1s)
# [Epoch 32] Train: ELBO -7.7396e-01 (7s) Test: ELBO -7.7139e-01, Accuracy 0.910 (1s)
# [Epoch 33] Train: ELBO -7.7326e-01 (6s) Test: ELBO -7.7055e-01, Accuracy 0.912 (1s)
# [Epoch 34] Train: ELBO -7.7269e-01 (7s) Test: ELBO -7.7063e-01, Accuracy 0.911 (1s)
# [Epoch 35] Train: ELBO -7.7210e-01 (8s) Test: ELBO -7.6895e-01, Accuracy 0.912 (1s)
# [Epoch 36] Train: ELBO -7.7161e-01 (8s) Test: ELBO -7.6850e-01, Accuracy 0.912 (1s)
# [Epoch 37] Train: ELBO -7.7141e-01 (7s) Test: ELBO -7.6942e-01, Accuracy 0.919 (0s)
# [Epoch 38] Train: ELBO -7.7068e-01 (7s) Test: ELBO -7.6764e-01, Accuracy 0.910 (0s)
# [Epoch 39] Train: ELBO -7.7020e-01 (7s) Test: ELBO -7.6855e-01, Accuracy 0.916 (0s)
# [Epoch 40] Train: ELBO -7.6983e-01 (7s) Test: ELBO -7.6720e-01, Accuracy 0.924 (0s)
# [Epoch 41] Train: ELBO -7.6931e-01 (7s) Test: ELBO -7.6663e-01, Accuracy 0.921 (0s)
# [Epoch 42] Train: ELBO -7.6902e-01 (7s) Test: ELBO -7.6667e-01, Accuracy 0.920 (0s)
# [Epoch 43] Train: ELBO -7.6857e-01 (7s) Test: ELBO -7.6677e-01, Accuracy 0.921 (0s)
# [Epoch 44] Train: ELBO -7.6855e-01 (7s) Test: ELBO -7.6708e-01, Accuracy 0.924 (0s)
# [Epoch 45] Train: ELBO -7.6808e-01 (7s) Test: ELBO -7.6551e-01, Accuracy 0.921 (0s)
# [Epoch 46] Train: ELBO -7.6758e-01 (7s) Test: ELBO -7.6497e-01, Accuracy 0.925 (0s)
# [Epoch 47] Train: ELBO -7.6715e-01 (7s) Test: ELBO -7.6481e-01, Accuracy 0.923 (0s)
# [Epoch 48] Train: ELBO -7.6679e-01 (7s) Test: ELBO -7.6471e-01, Accuracy 0.927 (0s)
# [Epoch 49] Train: ELBO -7.6689e-01 (7s) Test: ELBO -7.6473e-01, Accuracy 0.926 (0s)
# [Epoch 50] Train: ELBO -7.6632e-01 (7s) Test: ELBO -7.6539e-01, Accuracy 0.925 (0s)
# [Epoch 51] Train: ELBO -7.6613e-01 (7s) Test: ELBO -7.6387e-01, Accuracy 0.927 (1s)
# [Epoch 52] Train: ELBO -7.6572e-01 (7s) Test: ELBO -7.6367e-01, Accuracy 0.928 (1s)
# [Epoch 53] Train: ELBO -7.6555e-01 (7s) Test: ELBO -7.6425e-01, Accuracy 0.925 (1s)
# [Epoch 54] Train: ELBO -7.6504e-01 (8s) Test: ELBO -7.6315e-01, Accuracy 0.931 (1s)
# [Epoch 55] Train: ELBO -7.6492e-01 (7s) Test: ELBO -7.6308e-01, Accuracy 0.929 (1s)
# [Epoch 56] Train: ELBO -7.6473e-01 (7s) Test: ELBO -7.6378e-01, Accuracy 0.925 (1s)
# [Epoch 57] Train: ELBO -7.6439e-01 (7s) Test: ELBO -7.6264e-01, Accuracy 0.929 (0s)
# [Epoch 58] Train: ELBO -7.6408e-01 (7s) Test: ELBO -7.6245e-01, Accuracy 0.936 (0s)
# [Epoch 59] Train: ELBO -7.6402e-01 (7s) Test: ELBO -7.6218e-01, Accuracy 0.929 (0s)
# [Epoch 60] Train: ELBO -7.6384e-01 (7s) Test: ELBO -7.6205e-01, Accuracy 0.929 (0s)
# [Epoch 61] Train: ELBO -7.6360e-01 (7s) Test: ELBO -7.6157e-01, Accuracy 0.932 (0s)
# [Epoch 62] Train: ELBO -7.6339e-01 (7s) Test: ELBO -7.6220e-01, Accuracy 0.932 (1s)
# [Epoch 63] Train: ELBO -7.6312e-01 (7s) Test: ELBO -7.6108e-01, Accuracy 0.933 (1s)
# [Epoch 64] Train: ELBO -7.6293e-01 (7s) Test: ELBO -7.6108e-01, Accuracy 0.931 (1s)
# [Epoch 65] Train: ELBO -7.6277e-01 (7s) Test: ELBO -7.6119e-01, Accuracy 0.932 (1s)
# [Epoch 66] Train: ELBO -7.6244e-01 (7s) Test: ELBO -7.6047e-01, Accuracy 0.932 (1s)
# [Epoch 67] Train: ELBO -7.6217e-01 (7s) Test: ELBO -7.6094e-01, Accuracy 0.927 (1s)
# [Epoch 68] Train: ELBO -7.6230e-01 (7s) Test: ELBO -7.6139e-01, Accuracy 0.932 (0s)
# [Epoch 69] Train: ELBO -7.6187e-01 (8s) Test: ELBO -7.6074e-01, Accuracy 0.935 (1s)
# [Epoch 70] Train: ELBO -7.6165e-01 (10s) Test: ELBO -7.6085e-01, Accuracy 0.935 (1s)
# [Epoch 71] Train: ELBO -7.6145e-01 (7s) Test: ELBO -7.5990e-01, Accuracy 0.933 (1s)
# [Epoch 72] Train: ELBO -7.6181e-01 (8s) Test: ELBO -7.6021e-01, Accuracy 0.933 (1s)
# [Epoch 73] Train: ELBO -7.6116e-01 (9s) Test: ELBO -7.5970e-01, Accuracy 0.936 (1s)
# [Epoch 74] Train: ELBO -7.6103e-01 (8s) Test: ELBO -7.6093e-01, Accuracy 0.937 (1s)
# [Epoch 75] Train: ELBO -7.6117e-01 (7s) Test: ELBO -7.5993e-01, Accuracy 0.936 (0s)
# [Epoch 76] Train: ELBO -7.6071e-01 (7s) Test: ELBO -7.5890e-01, Accuracy 0.937 (0s)
# [Epoch 77] Train: ELBO -7.6069e-01 (7s) Test: ELBO -7.5942e-01, Accuracy 0.936 (0s)
# [Epoch 78] Train: ELBO -7.6035e-01 (7s) Test: ELBO -7.6018e-01, Accuracy 0.938 (1s)
# [Epoch 79] Train: ELBO -7.6026e-01 (7s) Test: ELBO -7.5971e-01, Accuracy 0.936 (0s)
# [Epoch 80] Train: ELBO -7.6006e-01 (7s) Test: ELBO -7.5983e-01, Accuracy 0.938 (1s)
# [Epoch 81] Train: ELBO -7.6002e-01 (8s) Test: ELBO -7.5965e-01, Accuracy 0.936 (0s)
# [Epoch 82] Train: ELBO -7.5977e-01 (7s) Test: ELBO -7.5919e-01, Accuracy 0.935 (0s)
# [Epoch 83] Train: ELBO -7.5978e-01 (7s) Test: ELBO -7.5884e-01, Accuracy 0.939 (1s)
# [Epoch 84] Train: ELBO -7.5956e-01 (7s) Test: ELBO -7.5844e-01, Accuracy 0.936 (1s)
# [Epoch 85] Train: ELBO -7.5925e-01 (7s) Test: ELBO -7.5805e-01, Accuracy 0.939 (1s)
# [Epoch 86] Train: ELBO -7.5957e-01 (9s) Test: ELBO -7.5831e-01, Accuracy 0.942 (1s)
# [Epoch 87] Train: ELBO -7.5922e-01 (7s) Test: ELBO -7.5822e-01, Accuracy 0.937 (1s)
# [Epoch 88] Train: ELBO -7.5911e-01 (7s) Test: ELBO -7.5760e-01, Accuracy 0.939 (1s)
# [Epoch 89] Train: ELBO -7.5881e-01 (7s) Test: ELBO -7.5782e-01, Accuracy 0.934 (1s)
# [Epoch 90] Train: ELBO -7.5858e-01 (7s) Test: ELBO -7.5709e-01, Accuracy 0.942 (1s)
# [Epoch 91] Train: ELBO -7.5860e-01 (8s) Test: ELBO -7.5814e-01, Accuracy 0.945 (1s)
# [Epoch 92] Train: ELBO -7.5834e-01 (7s) Test: ELBO -7.5861e-01, Accuracy 0.941 (0s)
# [Epoch 93] Train: ELBO -7.5855e-01 (7s) Test: ELBO -7.5731e-01, Accuracy 0.938 (0s)
# [Epoch 94] Train: ELBO -7.5823e-01 (7s) Test: ELBO -7.5772e-01, Accuracy 0.942 (1s)
# [Epoch 95] Train: ELBO -7.5809e-01 (7s) Test: ELBO -7.5649e-01, Accuracy 0.944 (0s)
# [Epoch 96] Train: ELBO -7.5806e-01 (7s) Test: ELBO -7.5630e-01, Accuracy 0.941 (1s)
# [Epoch 97] Train: ELBO -7.5777e-01 (7s) Test: ELBO -7.5759e-01, Accuracy 0.944 (1s)
# [Epoch 98] Train: ELBO -7.5766e-01 (7s) Test: ELBO -7.5699e-01, Accuracy 0.941 (1s)
# [Epoch 99] Train: ELBO -7.5772e-01 (7s) Test: ELBO -7.5671e-01, Accuracy 0.943 (1s)
# [Epoch 100] Train: ELBO -7.5754e-01 (7s) Test: ELBO -7.5681e-01, Accuracy 0.944 (0s)
# [Epoch 101] Train: ELBO -7.5748e-01 (7s) Test: ELBO -7.5793e-01, Accuracy 0.942 (0s)
# [Epoch 102] Train: ELBO -7.5717e-01 (7s) Test: ELBO -7.5596e-01, Accuracy 0.942 (0s)
# [Epoch 103] Train: ELBO -7.5700e-01 (7s) Test: ELBO -7.5601e-01, Accuracy 0.941 (0s)
# [Epoch 104] Train: ELBO -7.5687e-01 (7s) Test: ELBO -7.5624e-01, Accuracy 0.944 (1s)
# [Epoch 105] Train: ELBO -7.5687e-01 (6s) Test: ELBO -7.5595e-01, Accuracy 0.943 (0s)
# [Epoch 106] Train: ELBO -7.5687e-01 (6s) Test: ELBO -7.5585e-01, Accuracy 0.942 (0s)
# [Epoch 107] Train: ELBO -7.5673e-01 (6s) Test: ELBO -7.5554e-01, Accuracy 0.944 (1s)
# [Epoch 108] Train: ELBO -7.5658e-01 (7s) Test: ELBO -7.5542e-01, Accuracy 0.944 (0s)
# [Epoch 109] Train: ELBO -7.5650e-01 (7s) Test: ELBO -7.5645e-01, Accuracy 0.943 (0s)
# [Epoch 110] Train: ELBO -7.5621e-01 (7s) Test: ELBO -7.5640e-01, Accuracy 0.943 (0s)
# [Epoch 111] Train: ELBO -7.5645e-01 (7s) Test: ELBO -7.5551e-01, Accuracy 0.945 (0s)
# [Epoch 112] Train: ELBO -7.5612e-01 (7s) Test: ELBO -7.5504e-01, Accuracy 0.945 (0s)
# [Epoch 113] Train: ELBO -7.5602e-01 (7s) Test: ELBO -7.5618e-01, Accuracy 0.945 (0s)
# [Epoch 114] Train: ELBO -7.5603e-01 (7s) Test: ELBO -7.5555e-01, Accuracy 0.943 (1s)
# [Epoch 115] Train: ELBO -7.5596e-01 (7s) Test: ELBO -7.5478e-01, Accuracy 0.944 (0s)
# [Epoch 116] Train: ELBO -7.5565e-01 (7s) Test: ELBO -7.5529e-01, Accuracy 0.946 (0s)
# [Epoch 117] Train: ELBO -7.5581e-01 (7s) Test: ELBO -7.5638e-01, Accuracy 0.941 (0s)
# [Epoch 118] Train: ELBO -7.5579e-01 (7s) Test: ELBO -7.5545e-01, Accuracy 0.947 (0s)
# [Epoch 119] Train: ELBO -7.5542e-01 (7s) Test: ELBO -7.5543e-01, Accuracy 0.946 (1s)
# [Epoch 120] Train: ELBO -7.5549e-01 (8s) Test: ELBO -7.5499e-01, Accuracy 0.948 (0s)
# [Epoch 121] Train: ELBO -7.5540e-01 (7s) Test: ELBO -7.5492e-01, Accuracy 0.947 (0s)
# [Epoch 122] Train: ELBO -7.5528e-01 (7s) Test: ELBO -7.5540e-01, Accuracy 0.946 (0s)
# [Epoch 123] Train: ELBO -7.5499e-01 (7s) Test: ELBO -7.5539e-01, Accuracy 0.944 (1s)
# [Epoch 124] Train: ELBO -7.5505e-01 (7s) Test: ELBO -7.5427e-01, Accuracy 0.950 (0s)
# [Epoch 125] Train: ELBO -7.5502e-01 (7s) Test: ELBO -7.5431e-01, Accuracy 0.946 (0s)
# [Epoch 126] Train: ELBO -7.5484e-01 (7s) Test: ELBO -7.5510e-01, Accuracy 0.947 (1s)
# [Epoch 127] Train: ELBO -7.5471e-01 (7s) Test: ELBO -7.5476e-01, Accuracy 0.948 (1s)
# [Epoch 128] Train: ELBO -7.5477e-01 (7s) Test: ELBO -7.5348e-01, Accuracy 0.948 (0s)
# [Epoch 129] Train: ELBO -7.5449e-01 (7s) Test: ELBO -7.5510e-01, Accuracy 0.946 (0s)
# [Epoch 130] Train: ELBO -7.5474e-01 (7s) Test: ELBO -7.5401e-01, Accuracy 0.947 (0s)
# [Epoch 131] Train: ELBO -7.5450e-01 (7s) Test: ELBO -7.5393e-01, Accuracy 0.945 (0s)
# [Epoch 132] Train: ELBO -7.5440e-01 (7s) Test: ELBO -7.5438e-01, Accuracy 0.948 (0s)
# [Epoch 133] Train: ELBO -7.5442e-01 (7s) Test: ELBO -7.5372e-01, Accuracy 0.948 (0s)
# [Epoch 134] Train: ELBO -7.5410e-01 (7s) Test: ELBO -7.5476e-01, Accuracy 0.948 (1s)
# [Epoch 135] Train: ELBO -7.5416e-01 (8s) Test: ELBO -7.5407e-01, Accuracy 0.947 (1s)
# [Epoch 136] Train: ELBO -7.5407e-01 (7s) Test: ELBO -7.5422e-01, Accuracy 0.945 (0s)
# [Epoch 137] Train: ELBO -7.5400e-01 (6s) Test: ELBO -7.5404e-01, Accuracy 0.948 (0s)
# [Epoch 138] Train: ELBO -7.5380e-01 (6s) Test: ELBO -7.5355e-01, Accuracy 0.947 (0s)
# [Epoch 139] Train: ELBO -7.5386e-01 (6s) Test: ELBO -7.5370e-01, Accuracy 0.945 (0s)
# [Epoch 140] Train: ELBO -7.5364e-01 (6s) Test: ELBO -7.5485e-01, Accuracy 0.949 (0s)
# [Epoch 141] Train: ELBO -7.5353e-01 (6s) Test: ELBO -7.5331e-01, Accuracy 0.949 (0s)
# [Epoch 142] Train: ELBO -7.5363e-01 (6s) Test: ELBO -7.5356e-01, Accuracy 0.951 (0s)
# [Epoch 143] Train: ELBO -7.5341e-01 (6s) Test: ELBO -7.5259e-01, Accuracy 0.949 (0s)
# [Epoch 144] Train: ELBO -7.5374e-01 (6s) Test: ELBO -7.5381e-01, Accuracy 0.947 (0s)
# [Epoch 145] Train: ELBO -7.5328e-01 (6s) Test: ELBO -7.5293e-01, Accuracy 0.949 (0s)
# [Epoch 146] Train: ELBO -7.5329e-01 (6s) Test: ELBO -7.5374e-01, Accuracy 0.947 (0s)
# [Epoch 147] Train: ELBO -7.5335e-01 (6s) Test: ELBO -7.5251e-01, Accuracy 0.947 (0s)
# [Epoch 148] Train: ELBO -7.5303e-01 (6s) Test: ELBO -7.5383e-01, Accuracy 0.946 (0s)
# [Epoch 149] Train: ELBO -7.5321e-01 (6s) Test: ELBO -7.5330e-01, Accuracy 0.947 (0s)
# [Epoch 150] Train: ELBO -7.5294e-01 (6s) Test: ELBO -7.5298e-01, Accuracy 0.950 (0s)
# [Epoch 151] Train: ELBO -7.5292e-01 (6s) Test: ELBO -7.5269e-01, Accuracy 0.950 (0s)
# [Epoch 152] Train: ELBO -7.5286e-01 (6s) Test: ELBO -7.5316e-01, Accuracy 0.948 (0s)
# [Epoch 153] Train: ELBO -7.5258e-01 (6s) Test: ELBO -7.5377e-01, Accuracy 0.948 (1s)
# [Epoch 154] Train: ELBO -7.5264e-01 (6s) Test: ELBO -7.5259e-01, Accuracy 0.950 (0s)
# [Epoch 155] Train: ELBO -7.5272e-01 (6s) Test: ELBO -7.5252e-01, Accuracy 0.947 (0s)
# [Epoch 156] Train: ELBO -7.5262e-01 (6s) Test: ELBO -7.5213e-01, Accuracy 0.950 (0s)
# [Epoch 157] Train: ELBO -7.5251e-01 (6s) Test: ELBO -7.5254e-01, Accuracy 0.951 (0s)
# [Epoch 158] Train: ELBO -7.5262e-01 (6s) Test: ELBO -7.5199e-01, Accuracy 0.948 (0s)
# [Epoch 159] Train: ELBO -7.5243e-01 (6s) Test: ELBO -7.5306e-01, Accuracy 0.949 (0s)
# [Epoch 160] Train: ELBO -7.5223e-01 (6s) Test: ELBO -7.5328e-01, Accuracy 0.950 (0s)
# [Epoch 161] Train: ELBO -7.5232e-01 (6s) Test: ELBO -7.5237e-01, Accuracy 0.946 (0s)
# [Epoch 162] Train: ELBO -7.5229e-01 (6s) Test: ELBO -7.5194e-01, Accuracy 0.949 (1s)
# [Epoch 163] Train: ELBO -7.5235e-01 (6s) Test: ELBO -7.5157e-01, Accuracy 0.949 (0s)
# [Epoch 164] Train: ELBO -7.5216e-01 (6s) Test: ELBO -7.5266e-01, Accuracy 0.952 (1s)
# [Epoch 165] Train: ELBO -7.5211e-01 (6s) Test: ELBO -7.5302e-01, Accuracy 0.951 (0s)
# [Epoch 166] Train: ELBO -7.5185e-01 (6s) Test: ELBO -7.5228e-01, Accuracy 0.952 (0s)
# [Epoch 167] Train: ELBO -7.5189e-01 (6s) Test: ELBO -7.5286e-01, Accuracy 0.947 (0s)
# [Epoch 168] Train: ELBO -7.5185e-01 (6s) Test: ELBO -7.5218e-01, Accuracy 0.948 (0s)
# [Epoch 169] Train: ELBO -7.5171e-01 (6s) Test: ELBO -7.5175e-01, Accuracy 0.952 (0s)
# [Epoch 170] Train: ELBO -7.5181e-01 (6s) Test: ELBO -7.5208e-01, Accuracy 0.952 (0s)
# [Epoch 171] Train: ELBO -7.5146e-01 (6s) Test: ELBO -7.5197e-01, Accuracy 0.951 (0s)
# [Epoch 172] Train: ELBO -7.5134e-01 (6s) Test: ELBO -7.5179e-01, Accuracy 0.948 (0s)
# [Epoch 173] Train: ELBO -7.5167e-01 (6s) Test: ELBO -7.5170e-01, Accuracy 0.951 (1s)
# [Epoch 174] Train: ELBO -7.5148e-01 (6s) Test: ELBO -7.5123e-01, Accuracy 0.952 (0s)
# [Epoch 175] Train: ELBO -7.5137e-01 (7s) Test: ELBO -7.5118e-01, Accuracy 0.947 (1s)
# [Epoch 176] Train: ELBO -7.5141e-01 (7s) Test: ELBO -7.5159e-01, Accuracy 0.950 (0s)
# [Epoch 177] Train: ELBO -7.5130e-01 (6s) Test: ELBO -7.5167e-01, Accuracy 0.950 (0s)
# [Epoch 178] Train: ELBO -7.5105e-01 (6s) Test: ELBO -7.5135e-01, Accuracy 0.952 (1s)
# [Epoch 179] Train: ELBO -7.5101e-01 (6s) Test: ELBO -7.5145e-01, Accuracy 0.946 (0s)
# [Epoch 180] Train: ELBO -7.5115e-01 (6s) Test: ELBO -7.5176e-01, Accuracy 0.951 (0s)
# [Epoch 181] Train: ELBO -7.5084e-01 (6s) Test: ELBO -7.5143e-01, Accuracy 0.950 (0s)
# [Epoch 182] Train: ELBO -7.5101e-01 (6s) Test: ELBO -7.5064e-01, Accuracy 0.948 (0s)
# [Epoch 183] Train: ELBO -7.5070e-01 (6s) Test: ELBO -7.5102e-01, Accuracy 0.950 (0s)
# [Epoch 184] Train: ELBO -7.5076e-01 (6s) Test: ELBO -7.5104e-01, Accuracy 0.950 (0s)
# [Epoch 185] Train: ELBO -7.5074e-01 (6s) Test: ELBO -7.5083e-01, Accuracy 0.951 (1s)
# [Epoch 186] Train: ELBO -7.5067e-01 (6s) Test: ELBO -7.5134e-01, Accuracy 0.950 (1s)
# [Epoch 187] Train: ELBO -7.5071e-01 (6s) Test: ELBO -7.5205e-01, Accuracy 0.952 (0s)
# [Epoch 188] Train: ELBO -7.5072e-01 (6s) Test: ELBO -7.5132e-01, Accuracy 0.953 (0s)
# [Epoch 189] Train: ELBO -7.5049e-01 (6s) Test: ELBO -7.5100e-01, Accuracy 0.949 (0s)
# [Epoch 190] Train: ELBO -7.5049e-01 (6s) Test: ELBO -7.5018e-01, Accuracy 0.950 (0s)
# [Epoch 191] Train: ELBO -7.5052e-01 (6s) Test: ELBO -7.5134e-01, Accuracy 0.948 (0s)
# [Epoch 192] Train: ELBO -7.5041e-01 (6s) Test: ELBO -7.5099e-01, Accuracy 0.949 (0s)
# [Epoch 193] Train: ELBO -7.5022e-01 (6s) Test: ELBO -7.5076e-01, Accuracy 0.951 (1s)
# [Epoch 194] Train: ELBO -7.5026e-01 (6s) Test: ELBO -7.5075e-01, Accuracy 0.951 (0s)
# [Epoch 195] Train: ELBO -7.4990e-01 (6s) Test: ELBO -7.5022e-01, Accuracy 0.953 (0s)
# [Epoch 196] Train: ELBO -7.4994e-01 (6s) Test: ELBO -7.5053e-01, Accuracy 0.951 (0s)
# [Epoch 197] Train: ELBO -7.4994e-01 (6s) Test: ELBO -7.5049e-01, Accuracy 0.951 (0s)
# [Epoch 198] Train: ELBO -7.5001e-01 (6s) Test: ELBO -7.5035e-01, Accuracy 0.953 (0s)
# [Epoch 199] Train: ELBO -7.4974e-01 (6s) Test: ELBO -7.5075e-01, Accuracy 0.949 (0s)

# %%
if RESTORE:
    enc.load_state_dict(torch.load('%s/%s-%s-%s-enc.rar' % (WEIGHTS_PATH, MODEL_NAME, probtorch.__version__, torch.__version__)))
    dec.load_state_dict(torch.load('%s/%s-%s-%s-dec.rar' % (WEIGHTS_PATH, MODEL_NAME, probtorch.__version__, torch.__version__)))

# %%
print('[predicted] ELBO: %e, ACCURACY: %f' % test(test_data, enc, dec, infer=False))
print('[inferred] ELBO: %e, ACCURACY: %f' % test(test_data, enc, dec, infer=True))
# Out:
# [predicted] ELBO: -7.506542e-01, ACCURACY: 0.933606
# [inferred] ELBO: -7.507431e-01, ACCURACY: 0.947716

# %% [markdown]
# # Visualize Embeddings

# %%
import numpy as np
ys = []
zs = []
for (x, y) in test_data:
    if len(x) == NUM_BATCH:
        images = Variable(x).view(-1, NUM_PIXELS)
        if CUDA:
            q = enc(images.cuda())
            z = q['styles'].value.data.cpu().numpy()
        else:
            q = enc(images)
            z = q['styles'].value.data.numpy()
        zs.append(z)
        ys.append(y.numpy())
ys = np.concatenate(ys,0)
zs = np.concatenate(zs,0)

# %%
# run TSNE when number of latent dims exceeds 2
if NUM_STYLE > 2:
    from sklearn.manifold import TSNE
    zs2 = TSNE().fit_transform(zs)
    zs2_mean = zs2.mean(0)
    zs2_std = zs2.std(0)
else:
    zs2 = zs

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# display a 2D plot of the digit classes in the latent space
fig = plt.figure(figsize=(6,6))
ax = plt.gca()

colors = []
for k in range(10):
    m = (ys == k)
    p = ax.scatter(zs2[m, 0], zs2[m, 1], label='y=%d' % k, alpha=0.5, s=5)
    colors.append(p.get_facecolor())
ax.legend()

fig.tight_layout()
#fig.savefig('images/%s-%02d-encodings.png' % (MODEL_NAME, NUM_STYLE), dpi=300)

x_lim = ax.get_xlim()
y_lim = ax.get_ylim()

# %%
# display a 2D plot of the digit classes in the latent space
fig = plt.figure(figsize=(10,4.25))

for k in range(10):
    ax = plt.subplot(2,5,k+1)
    m = (ys == k)
    ax.scatter(zs2[m, 0], zs2[m, 1], alpha=0.5, s=5, c=colors[k])
    ax.set_xlim(x_lim)
    ax.set_ylim(y_lim)
    ax.set_title('y=%d' % k)

fig.tight_layout()

# %% [markdown]
# # Visualize Reconstructed Digits

# %%
x,_ = next(iter(train_data))
x_var = Variable(x.view(-1, NUM_PIXELS))
if CUDA:
    q = enc(x_var.cuda())
    p = dec(x_var.cuda(), q)
    x_mean = p['images'].value.view(NUM_BATCH, 28, 28).data.cpu().numpy()
else:
    q = enc(x_var)
    p = dec(x_var, q)
    x_mean = p['images'].value.view(NUM_BATCH, 28, 28).data.numpy().squeeze()
    
fig = plt.figure(figsize=(12,5.25))
for k in range(5):
    ax = plt.subplot(2, 5, k+1)
    ax.imshow(x[k].squeeze())
    #ax.set_title("original")
    plt.axis("off")
    ax = plt.subplot(2, 5, k+6)
    ax.imshow(x_mean[k].squeeze())
    #ax.set_title("reconstructed")
    plt.axis("off")
    
fig.tight_layout()
#fig.savefig('images/%s-%02d-reconstructions-separate.png' % (MODEL_NAME, NUM_STYLE), dpi=300, facecolor=[0,0,0,0])

# %%
# display a 2D manifold of the digits
n = 7  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# linearly spaced coordinates on the unit square were transformed through the inverse CDF (ppf) of the Gaussian
# to produce values of the latent variables z, since the prior of the latent space is Gaussian
grid_x = norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))
null_image = Variable(torch.Tensor(np.zeros((1, 784))))

plt.figure(figsize=(12, 30))
for y in range(10):
    plt.subplot(5, 2, y+1)
    y_hot = np.zeros((1,10))
    y_hot[0,y] = 1
    y_hot = Variable(torch.FloatTensor(y_hot))
    my = (ys == y)
    for i, z0i in enumerate(grid_x):
        for j, z1j in enumerate(grid_y[-1::-1]):
            z = np.array([[z0i, z1j]])
            if NUM_STYLE > 2:
                z = zs2_mean[None,:] + zs2_std[None,:] * z
                n = ((zs2[my] - z)**2).sum(1).argmin()
                z = zs[my][n][None,:]
            z = Variable(torch.FloatTensor(z))
            if CUDA:
                p = dec(null_image.cuda(), {'styles': z.cuda(), 'digits': y_hot.cuda()})
                images = p['images'].value.data.cpu().numpy()
            else:
                p = dec(null_image, {'styles': z, 'digits': y_hot})
                images = p['images'].value.data.numpy()
            digit = images.reshape(digit_size, digit_size)
            figure[j * digit_size: (j + 1) * digit_size,
                   i * digit_size: (i + 1) * digit_size] = digit
    plt.imshow(figure)
    plt.title('y=%d' % y)
    plt.axis('off')
plt.show()
